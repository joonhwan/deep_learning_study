# %% [markdown]
# <a href="https://colab.research.google.com/github/joonhwan/deep_learning_study/blob/main/_6_%EC%BC%80%EB%9D%BC%EC%8A%A4_%EC%BB%A8%EB%B3%BC%EB%A3%A8%EC%85%98_%EC%8B%A0%EA%B2%BD%EB%A7%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 컨볼루션 신경망(Convolution Neural Network, CNN)

# %% [markdown]
# ## 주요 레이어

# %% [markdown]
# ### Conv2D
#
# - `tensorflow.keras.layers.Conv2D`
#
# - `tf.nn.conv2d`

# %%
# Out:
# uint8
# (427, 640, 3)

# %%
# Out:
# float64
# (427, 640, 3)

# %%
# Out:
# (2, 427, 640, 3)

# %%
# Out:
# (7, 7, 3, 2)

# %%
# Out:
# (2, 427, 640, 2)

# %% [markdown]
# ### MaxPool2D
#
# - 텐서플로 저수준 딥러닝 API
#   - `tf.nn.max_pool`
#   - 사용자가 사이즈를 맞춰줘야함
#   - 케라스의 모델의 층으로 사용하고 싶으면 Lambda층으로 감싸줘야함
#
# - 케라스 고수준 API
#   - `keras.layers.MaxPool2D`

# %%
# Out:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# <ipython-input-12-5a68136d9361> in <module>()
#       2                         ksize=(1, 1, 1, 3),
#       3                         strides=(1, 1, 1, 3),
# ----> 4                         padding='VALID')
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_ops.py in max_pool_v2(input, ksize, strides, padding, data_format, name)
#    4469       padding=padding,
#    4470       data_format=data_format,
# -> 4471       name=name)
#    4472 # pylint: enable=redefined-builtin
#    4473
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_nn_ops.py in max_pool(input, ksize, strides, padding, data_format, name)
#    5241       return _result
#    5242     except _core._NotOkStatusException as e:
# -> 5243       _ops.raise_from_not_ok_status(e, name)
#    5244     except _core._FallbackException:
#    5245       pass
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6841   message = e.message + (" name: " + name if name is not None else "")
#    6842   # pylint: disable=protected-access
# -> 6843   six.raise_from(core._status_to_exception(e.code, message), None)
#    6844   # pylint: enable=protected-access
#    6845
#
# /usr/local/lib/python3.6/dist-packages/six.py in raise_from(value, from_value)
#
# UnimplementedError: Depthwise max pooling is currently only implemented for CPU devices. [Op:MaxPool]

# %% [markdown]
# ### AvgPool2D
#
# - 텐서플로 저수준 딥러닝 API
#   - `tf.nn.avg_pool`
#
# - 케라스 고수준 API
#   - `keras.layers.AvgPool2D`

# %% [markdown]
# ### GlobalAvgPool2D (전역 평균 풀링 층)
#
# - `keras.layers.GlobalAvgPool2D()`
#
# - 특징 맵 각각의 평균값을 출력하는 것이므로, 특성맵에 있는 대부분의 정보를 잃음
#
# - 출력층에는 유용할 수 있음

# %% [markdown]
# ## 예제로 보는 CNN 구조와 학습
# - 모델 구현은 참고만
#
#
# - [런타임] - [런타임 유형변경] - GPU 변경

# %% [markdown]
# ### 일반적인 구조

# %% [markdown]
# #### modules import

# %% [markdown]
# #### 데이터 로드 및 전처리

# %% [markdown]
# #### CNN을 위한 간단한 모델

# %% [markdown]
# #### 모델 컴파일

# %% [markdown]
# #### Hyper Parameters

# %% [markdown]
# #### 모델 학습
# - `validation_split` 을 통해 검증 데이터셋을 생성

# %% [markdown]
# ### LeNet-5
#
# - 필기체 인식을 위한 모델
#
#   <img src="https://hoya012.github.io/assets/img/image_classification_guidebook/1.PNG">
#
#   <sub>https://www.researchgate.net/figure/The-LeNet-5-Architecture-a-convolutional-neural-network_fig4_321586653</sub>

# %% [markdown]
# - 코드 출처 : http://datahacker.rs/lenet-5-implementation-tensorflow-2-0/

# %% [markdown]
# #### module import

# %% [markdown]
# #### 데이터 로드 및 전처리

# %% [markdown]
# #### 모델 구성 및 컴파일

# %% [markdown]
# #### Hyper Parameters

# %% [markdown]
# #### 모델 학습

# %% [markdown]
# #### 학습 결과 시각화

# %% [markdown]
# #### 모델 평가
